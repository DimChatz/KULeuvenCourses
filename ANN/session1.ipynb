# %%
# !pip install keras_core
# Out:
# Collecting keras_core
#   Downloading keras_core-0.1.7-py3-none-any.whl (950 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras_core) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras_core) (1.25.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras_core) (13.7.1)
# Collecting namex (from keras_core)
#   Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras_core) (3.9.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from keras_core) (0.1.8)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras_core) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras_core) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras_core) (0.1.2)
# Installing collected packages: namex, keras_core
# Successfully installed keras_core-0.1.7 namex-0.0.8

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import os
import time
import copy
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import pandas as pd

os.environ["KERAS_BACKEND"] = "torch"
import keras_core as keras
# Out:
# Using PyTorch backend.

# %% [markdown]
# # The Perceptron and beyond

# %% [markdown]
# In this section, we consider a regression task where the underlying data generation process is as follows:
# $$ y = - \sin{(0.8 * x)}$$
#
# Note that in this example there is no noise in the data, a case that you will rarely encounter in practice.

# %%
# Defining our dataset

x_train = np.linspace(0, 3, 50)
y_train = - np.sin(0.8*x_train)

# Plotting the dataset

plt.figure()
plt.xlabel("x")
plt.ylabel("y")
plt.scatter(x_train, y_train, color= "firebrick")
plt.show()

# %% [markdown]
# The following function can be used to instantiate the perceptron

# %%
def perceptron(input_shape= [1], units= 1, activation= None):
    model = keras.Sequential(
        [
            keras.layers.Input(shape= input_shape),
            keras.layers.Dense(units= units, activation= activation)
        ]
    )
    return model

linear_model = perceptron()

# You can vizualize a summary of your model by commenting out the following line.
# Here it is an affine function in dimension 1, thus having two parameters.

# linear_model.summary()

# %% [markdown]
# To fit a model in keras, one must first compile it, that is specify the loss and optimizer. Here they are respectively chosen as the mean squared error and gradient descent. Observe that the batch size is the same as the size of the training dataset, resulting in batch gradient descent.
#
# You can play with the learning rate and number of epochs to understand how the training algorithm behaves.

# %%
linear_model.compile(
    loss = keras.losses.MeanSquaredError(),
    optimizer = keras.optimizers.SGD(learning_rate= 0.2)
)
history = linear_model.fit(x_train, y_train, epochs= 35, batch_size= 50)

plt.figure()
plt.xlabel('epoch')
plt.ylabel('training loss')
plt.plot(history.history['loss'])
plt.show()
# Out:
# Epoch 1/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 644ms/step - loss: 0.1554
# Epoch 2/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0795
# Epoch 3/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0564
# Epoch 4/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0486
# Epoch 5/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0452
# Epoch 6/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0433
# Epoch 7/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0419
# Epoch 8/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0408
# Epoch 9/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0399
# Epoch 10/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0392
# Epoch 11/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0385
# Epoch 12/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0380
# Epoch 13/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0376
# Epoch 14/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0372
# Epoch 15/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0369
# Epoch 16/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0366
# Epoch 17/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0364
# Epoch 18/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0362
# Epoch 19/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0360
# Epoch 20/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0359
# Epoch 21/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0358
# Epoch 22/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0357
# Epoch 23/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0356
# Epoch 24/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0355
# Epoch 25/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0355
# Epoch 26/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0354
# Epoch 27/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0354
# Epoch 28/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0353
# Epoch 29/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0353
# Epoch 30/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0353
# Epoch 31/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0353
# Epoch 32/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0353
# Epoch 33/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0352
# Epoch 34/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0352
# Epoch 35/35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0352

# %% [markdown]
# Having trained the model, we can now use it in prediction.

# %%
y_pred_linear = linear_model.predict(x_train)

plt.figure()
plt.xlabel("x")
plt.ylabel("y")
plt.scatter(x_train, y_train, color='firebrick', label= 'true function')
plt.plot(x_train, y_pred_linear, color= 'teal', label= 'linear model')
plt.legend()
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# Beyond this simple perceptron, we now consider a 2-layers neural network model.

# %%
def neural_net_2layers(input_shape= [1], units= 16, activation= 'sigmoid'):
    model = keras.Sequential(
        [
            keras.layers.Input(shape= input_shape),
            keras.layers.Dense(units= units, activation= activation),
            keras.layers.Dense(units= 1)
        ]
    )
    return model

# %% [markdown]
# You can train the model, and play with the hyperparameters to answer the questions.

# %%
net = neural_net_2layers(units= 10)

net.compile(
    loss = keras.losses.MeanSquaredError(),
    optimizer = keras.optimizers.Adam(learning_rate= 0.1)  # Try also the (batch) SGD optimizer
)

history = net.fit(x_train, y_train, epochs= 300, batch_size= 25, verbose= 0)

plt.figure()
plt.xlabel('epoch')
plt.ylabel('training loss')
plt.plot(np.log(history.history['loss']))
plt.show()

# %%
y_pred_2l = net.predict(x_train)

plt.figure()
plt.xlabel("x")
plt.ylabel("y")
plt.scatter(x_train, y_train, color='firebrick', label = 'true function')
plt.plot(x_train, y_pred_linear, color= 'teal', label = 'linear model')
plt.plot(x_train, y_pred_2l, color= 'indigo', label = '2-l net')
plt.legend()
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %% [markdown]
# # In the wild jungle of training algorithms

# %% [markdown]
# ## Small model
#
# We first start by defining a simple dataset based on a modified cosine surface. This will allows us to test small models, and in particular 2nd order optimization algorithms. While <tt>keras</tt> is high-level deep learning library, we will dive into the depths of <tt>pytorch</tt> to have more control over the optimization schemes.

# %%
def f(x, y):
    return(torch.sin(0.8*(x**2 + y**2)) / (x**2 + y**2)**(0.9))

noise_level = 0
mesh_size = 40
t = torch.linspace(-3, 3, mesh_size)
x, y = torch.meshgrid(t, t)
z = f(x, y)
z_noisy = z + noise_level * torch.randn(mesh_size, mesh_size)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(x, y, z_noisy,cmap='viridis', edgecolor='none')
ax.set_title('Surface plot')
plt.show()


# dataset creation
x_train = torch.vstack([x.ravel(), y.ravel()]).T
y_train = z_noisy.ravel()
y_test = z.ravel()

# %% [markdown]
# The following class encodes the architecture of a neural network with two hidden layers, for when the input data is 2-dimensional. We provide a simplified <tt>fit</tt> method to train the neural network. You are encouraged to understand the code, and what executing the functions will return so as to draw legitimate conclusions about the experiments.

# %%
class Net3L(nn.Module):

    def __init__(self, n_neurons_l1= 10, n_neurons_l2= 10):
        super(Net3L, self).__init__()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(2, n_neurons_l1),
            nn.ReLU(),
            nn.Linear(n_neurons_l1, n_neurons_l2),
            nn.ReLU(),
            nn.Linear(n_neurons_l2, 1)
        )

    def forward(self, x):
        return self.linear_relu_stack(x)

    def fit(self, x_train, y_train, optimizer, batch_size, n_epochs_max):
        # Instantiate the train loader
        train_data = TensorDataset(x_train, y_train)
        train_loader = DataLoader(dataset =train_data, batch_size= batch_size, shuffle= True)
        # Beginning the optimization algorithm
        loss_list = []
        for n_epochs in range(n_epochs_max):
            # We train for a fixed number of epochs
            for x_batch, y_batch in train_loader:
                def closure():
                    optimizer.zero_grad()
                    output = self.forward(x_batch)
                    loss = nn.MSELoss()(output.squeeze(-1), y_batch)
                    loss.backward()
                    return loss
                loss = optimizer.step(closure)
            loss_list.append(loss.item())
        return loss_list

    def evaluate(self, x_test, y_test):
      y_pred = self(x_test).squeeze(-1)
      return (nn.MSELoss()(y_pred, y_test)).item()

# %% [markdown]
# The cell below gives an example of what happens when the training is done using the L-BFGS algorithm. It can be adapted to other algorithms by modifying the arguments passed to the <tt>fit</tt> method.

# %%
net = Net3L(50, 50)
loss_list = net.fit(x_train, y_train, torch.optim.LBFGS(net.parameters(), lr=1, max_iter=1, line_search_fn='strong_wolfe'), 1600, 2000)

plt.figure()
plt.xlabel('Epoch number')
plt.ylabel('Training MSE')
plt.plot(loss_list)
plt.show()

y_pred = net(x_train).detach().squeeze(-1)

fig, ax = plt.subplots(1, 2, figsize=(10, 10), subplot_kw={'projection': '3d'})
#
ax[0].plot_trisurf(x_train[:, 0], x_train[:, 1], y_pred, vmin=y_train.min(), cmap=cm.viridis)
ax[0].set_xlabel('x')
ax[0].set_ylabel('y')
ax[0].set_zlabel('z')
ax[0].set_title('Surface')
#
ax[1].plot_trisurf(x_train[:, 0], x_train[:, 1], (y_pred-y_train)**2, vmin=0, cmap=cm.viridis)
ax[1].set_xlabel('x')
ax[1].set_ylabel('y')
ax[1].set_zlabel('z')
ax[1].set_title('Squared residuals')
plt.show()

print('Training error:', net.evaluate(x_train, y_train))
print('Test error:', net.evaluate(x_train, y_test))
# Out:
# Training error: 0.0001767891808412969
# Test error: 0.0001767891808412969

# %%
# Example with a list of optimizers (running this cell takes ~5min with the default parameters)
net = Net3L(10, 10)
# We create copies of this net so that every optimizer starts with the same initialization.
net_list = [copy.deepcopy(net) for i in range(5)]
# The number of epochs and other hyperparameters can (and should) be adapted to the point you're trying to make.
n_epochs = 2500
optim1 = torch.optim.SGD(params=net_list[0].parameters(), lr=0.05)
optim2 = torch.optim.SGD(params=net_list[1].parameters(), lr=0.1)
optim3 = torch.optim.SGD(params=net_list[2].parameters(), lr=0.1, momentum=0.9, nesterov= True)
optim4 = torch.optim.Adam(params=net_list[3].parameters())
optim5 = torch.optim.LBFGS(params=net_list[4].parameters(), lr=1, max_iter=1, line_search_fn='strong_wolfe')

optimizer_list = [optim1, optim2, optim3, optim4, optim5]
batch_sizes_list = [1600, 40, 400, 400, 1600]
times_list = []
loss_meta_list = []
eval_list = []

for i, optimizer in enumerate(optimizer_list):
    t0 = time.time()
    loss_list = net_list[i].fit(x_train, y_train, optimizer= optimizer, batch_size= batch_sizes_list[i], n_epochs_max= n_epochs)
    t1 = time.time()
    times_list.append(t1-t0)
    loss_meta_list.append(loss_list)
    eval_list.append(net_list[i].evaluate(x_train, y_test))

# %%
colors = cm.tab10(torch.linspace(0, 1, 5))
plt.figure()
plt.xlabel('Epochs')
plt.ylabel('Training MSE')
for i in range(5):
    plt.plot(loss_meta_list[i], color= colors[i])
plt.legend([f"optim{i+1}: {round(times_list[i], 2)}s" for i in range(5)])
plt.title("Network of 10 units")
plt.show()
print('Training times:', [f"optim{i+1}: {times_list[i]:.2f}s" for i in range(5)])
print('Evaluation performances:', [f"optim{i+1}: {eval_list[i]:1.3e}" for i in range(5)])
# Out:
# Training times: ['optim1: 43.88s', 'optim2: 124.99s', 'optim3: 43.14s', 'optim4: 46.10s', 'optim5: 53.26s']
# Evaluation performances: ['optim1: 1.435e-02', 'optim2: 1.776e-03', 'optim3: 2.315e-03', 'optim4: 2.924e-03', 'optim5: 1.927e-03']

# %%
# Example with a list of optimizers (running this cell takes ~5min with the default parameters)
net = Net3L(30, 30)
# We create copies of this net so that every optimizer starts with the same initialization.
net_list = [copy.deepcopy(net) for i in range(5)]
# The number of epochs and other hyperparameters can (and should) be adapted to the point you're trying to make.
n_epochs = 2500
optim1 = torch.optim.SGD(params=net_list[0].parameters(), lr=0.05)
optim2 = torch.optim.SGD(params=net_list[1].parameters(), lr=0.1)
optim3 = torch.optim.SGD(params=net_list[2].parameters(), lr=0.1, momentum=0.9, nesterov= True)
optim4 = torch.optim.Adam(params=net_list[3].parameters())
optim5 = torch.optim.LBFGS(params=net_list[4].parameters(), lr=1, max_iter=1, line_search_fn='strong_wolfe')

optimizer_list = [optim1, optim2, optim3, optim4, optim5]
batch_sizes_list = [1600, 40, 400, 400, 1600]
times_list = []
loss_meta_list = []
eval_list = []

for i, optimizer in enumerate(optimizer_list):
    t0 = time.time()
    loss_list = net_list[i].fit(x_train, y_train, optimizer= optimizer, batch_size= batch_sizes_list[i], n_epochs_max= n_epochs)
    t1 = time.time()
    times_list.append(t1-t0)
    loss_meta_list.append(loss_list)
    eval_list.append(net_list[i].evaluate(x_train, y_test))

# %%
colors = cm.tab10(torch.linspace(0, 1, 5))
plt.figure()
plt.xlabel('Epochs')
plt.ylabel('Training MSE')
for i in range(5):
    plt.plot(loss_meta_list[i], color= colors[i])
plt.legend([f"optim{i+1}: {round(times_list[i], 2)}s" for i in range(5)])
plt.title("Network of 30 units")
plt.show()
print('Training times:', [f"optim{i+1}: {times_list[i]:.2f}s" for i in range(5)])
print('Evaluation performances:', [f"optim{i+1}: {eval_list[i]:1.3e}" for i in range(5)])
# Out:
# Training times: ['optim1: 42.27s', 'optim2: 124.54s', 'optim3: 43.80s', 'optim4: 47.76s', 'optim5: 54.57s']
# Evaluation performances: ['optim1: 9.938e-03', 'optim2: 8.629e-04', 'optim3: 1.042e-03', 'optim4: 8.627e-04', 'optim5: 4.739e-04']

# %%
# Example with a list of optimizers (running this cell takes ~5min with the default parameters)
net = Net3L(50, 50)
# We create copies of this net so that every optimizer starts with the same initialization.
net_list = [copy.deepcopy(net) for i in range(5)]
# The number of epochs and other hyperparameters can (and should) be adapted to the point you're trying to make.
n_epochs = 2500
optim1 = torch.optim.SGD(params=net_list[0].parameters(), lr=0.05)
optim2 = torch.optim.SGD(params=net_list[1].parameters(), lr=0.1)
optim3 = torch.optim.SGD(params=net_list[2].parameters(), lr=0.1, momentum=0.9, nesterov= True)
optim4 = torch.optim.Adam(params=net_list[3].parameters())
optim5 = torch.optim.LBFGS(params=net_list[4].parameters(), lr=1, max_iter=1, line_search_fn='strong_wolfe')

optimizer_list = [optim1, optim2, optim3, optim4, optim5]
batch_sizes_list = [1600, 40, 400, 400, 1600]
times_list = []
loss_meta_list = []
eval_list = []

for i, optimizer in enumerate(optimizer_list):
    t0 = time.time()
    loss_list = net_list[i].fit(x_train, y_train, optimizer= optimizer, batch_size= batch_sizes_list[i], n_epochs_max= n_epochs)
    t1 = time.time()
    times_list.append(t1-t0)
    loss_meta_list.append(loss_list)
    eval_list.append(net_list[i].evaluate(x_train, y_test))

# %%
colors = cm.tab10(torch.linspace(0, 1, 5))
plt.figure()
plt.xlabel('Epochs')
plt.ylabel('Training MSE')
for i in range(5):
    plt.plot(loss_meta_list[i], color= colors[i])
plt.legend([f"optim{i+1}: {round(times_list[i], 2)}s" for i in range(5)])
plt.title("Network of 50 units")
plt.show()
print('Training times:', [f"optim{i+1}: {times_list[i]:.2f}s" for i in range(5)])
print('Evaluation performances:', [f"optim{i+1}: {eval_list[i]:1.3e}" for i in range(5)])
# Out:
# Training times: ['optim1: 43.80s', 'optim2: 127.71s', 'optim3: 45.53s', 'optim4: 49.51s', 'optim5: 58.44s']
# Evaluation performances: ['optim1: 9.181e-03', 'optim2: 5.410e-04', 'optim3: 7.865e-04', 'optim4: 2.475e-04', 'optim5: 2.327e-04']

# %%
def f(x, y):
    return(torch.sin(0.8*(x**2 + y**2)) / (x**2 + y**2)**(0.9))

noise_level = 0.15
mesh_size = 40
t = torch.linspace(-3, 3, mesh_size)
x, y = torch.meshgrid(t, t)
z = f(x, y)
z_noisy = z + noise_level * torch.randn(mesh_size, mesh_size)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(x, y, z_noisy,cmap='viridis', edgecolor='none')
ax.set_title('Surface plot')
plt.show()


# dataset creation
x_train = torch.vstack([x.ravel(), y.ravel()]).T
y_train = z_noisy.ravel()
y_test = z.ravel()

# %%
net = Net3L(50, 50)
loss_list = net.fit(x_train, y_train, torch.optim.LBFGS(net.parameters(), lr=1, max_iter=1, line_search_fn='strong_wolfe'), 1600, 2000)

plt.figure()
plt.xlabel('Epoch number')
plt.ylabel('Training MSE')
plt.plot(loss_list)
plt.show()

y_pred = net(x_train).detach().squeeze(-1)

fig, ax = plt.subplots(1, 2, figsize=(10, 10), subplot_kw={'projection': '3d'})
#
ax[0].plot_trisurf(x_train[:, 0], x_train[:, 1], y_pred, vmin=y_train.min(), cmap=cm.viridis)
ax[0].set_xlabel('x')
ax[0].set_ylabel('y')
ax[0].set_zlabel('z')
ax[0].set_title('Surface')
#
ax[1].plot_trisurf(x_train[:, 0], x_train[:, 1], (y_pred-y_train)**2, vmin=0, cmap=cm.viridis)
ax[1].set_xlabel('x')
ax[1].set_ylabel('y')
ax[1].set_zlabel('z')
ax[1].set_title('Squared residuals')
plt.show()

print('Training error:', net.evaluate(x_train, y_train))
print('Test error:', net.evaluate(x_train, y_test))
# Out:
# Training error: 0.01785292662680149
# Test error: 0.005187963135540485

# %%
def f(x, y):
    return(torch.sin(0.8*(x**2 + y**2)) / (x**2 + y**2)**(0.9))

noise_level = 0.5
mesh_size = 40
t = torch.linspace(-3, 3, mesh_size)
x, y = torch.meshgrid(t, t)
z = f(x, y)
z_noisy = z + noise_level * torch.randn(mesh_size, mesh_size)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(x, y, z_noisy,cmap='viridis', edgecolor='none')
ax.set_title('Surface plot')
plt.show()


# dataset creation
x_train = torch.vstack([x.ravel(), y.ravel()]).T
y_train = z_noisy.ravel()
y_test = z.ravel()

# %%
net = Net3L(50, 50)
loss_list = net.fit(x_train, y_train, torch.optim.LBFGS(net.parameters(), lr=1, max_iter=1, line_search_fn='strong_wolfe'), 1600, 2000)

plt.figure()
plt.xlabel('Epoch number')
plt.ylabel('Training MSE')
plt.plot(loss_list)
plt.show()

y_pred = net(x_train).detach().squeeze(-1)

fig, ax = plt.subplots(1, 2, figsize=(10, 10), subplot_kw={'projection': '3d'})
#
ax[0].plot_trisurf(x_train[:, 0], x_train[:, 1], y_pred, vmin=y_train.min(), cmap=cm.viridis)
ax[0].set_xlabel('x')
ax[0].set_ylabel('y')
ax[0].set_zlabel('z')
ax[0].set_title('Surface')
#
ax[1].plot_trisurf(x_train[:, 0], x_train[:, 1], (y_pred-y_train)**2, vmin=0, cmap=cm.viridis)
ax[1].set_xlabel('x')
ax[1].set_ylabel('y')
ax[1].set_zlabel('z')
ax[1].set_title('Squared residuals')
plt.show()

print('Training error:', net.evaluate(x_train, y_train))
print('Test error:', net.evaluate(x_train, y_test))
# Out:
# Training error: 0.16869531571865082
# Test error: 0.09165602922439575

# %%
# Example with a list of optimizers (running this cell takes ~5min with the default parameters)
net = Net3L(50, 50)
# We create copies of this net so that every optimizer starts with the same initialization.
net_list = [copy.deepcopy(net) for i in range(5)]
# The number of epochs and other hyperparameters can (and should) be adapted to the point you're trying to make.
n_epochs = 2500
optim1 = torch.optim.SGD(params=net_list[0].parameters(), lr=0.05)
optim2 = torch.optim.SGD(params=net_list[1].parameters(), lr=0.1)
optim3 = torch.optim.SGD(params=net_list[2].parameters(), lr=0.1, momentum=0.9, nesterov= True)
optim4 = torch.optim.Adam(params=net_list[3].parameters())
optim5 = torch.optim.LBFGS(params=net_list[4].parameters(), lr=1, max_iter=1, line_search_fn='strong_wolfe')

optimizer_list = [optim1, optim2, optim3, optim4, optim5]
batch_sizes_list = [1600, 40, 400, 400, 1600]
times_list = []
loss_meta_list = []
eval_list = []

for i, optimizer in enumerate(optimizer_list):
    t0 = time.time()
    loss_list = net_list[i].fit(x_train, y_train, optimizer= optimizer, batch_size= batch_sizes_list[i], n_epochs_max= n_epochs)
    t1 = time.time()
    times_list.append(t1-t0)
    loss_meta_list.append(loss_list)
    eval_list.append(net_list[i].evaluate(x_train, y_test))

# %%
colors = cm.tab10(torch.linspace(0, 1, 5))
plt.figure()
plt.xlabel('Epochs')
plt.ylabel('Training MSE')
for i in range(5):
    plt.plot(loss_meta_list[i], color= colors[i])
plt.legend([f"optim{i+1}: {round(times_list[i], 2)}s" for i in range(5)])
plt.show()
print('Training times:', [f"optim{i+1}: {times_list[i]:.2f}s" for i in range(5)])
print('Evaluation performances:', [f"optim{i+1}: {eval_list[i]:1.3e}" for i in range(5)])
# Out:
# Training times: ['optim1: 45.51s', 'optim2: 126.11s', 'optim3: 44.85s', 'optim4: 48.52s', 'optim5: 55.85s']
# Evaluation performances: ['optim1: 1.766e-02', 'optim2: 3.316e-02', 'optim3: 2.937e-02', 'optim4: 3.081e-02', 'optim5: 8.527e-02']

# %% [markdown]
# ## Towards a bigger model
#
# We now switch to a bigger model, used to perform classification over the MNIST dataset. This example is widely known in the machine learning community, and we follow the code in the footsteps of François Chollet, the creator of the <tt>keras</tt> library (https://keras.io/examples/vision/mnist_convnet/).

# %%
# Model / data parameters
num_classes = 10
input_shape = (28, 28, 1)

# Load the data and split it between train and test sets
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")


# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %% [markdown]
# The following cell deals with the training of the model. Can you change the optimizer while still retaining the capabilities of the model trained with adam ?

# %%
batch_size = 128
epochs = 15

model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        keras.layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        keras.layers.MaxPooling2D(pool_size=(2, 2)),
        keras.layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
        keras.layers.MaxPooling2D(pool_size=(2, 2)),
        keras.layers.Flatten(),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(num_classes, activation="softmax"),
    ]
)

# Modify the optimizer here
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 69s 163ms/step - accuracy: 0.7668 - loss: 0.7880 - val_accuracy: 0.9762 - val_loss: 0.0843
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 43s 102ms/step - accuracy: 0.9630 - loss: 0.1241 - val_accuracy: 0.9852 - val_loss: 0.0590
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 49s 115ms/step - accuracy: 0.9749 - loss: 0.0835 - val_accuracy: 0.9875 - val_loss: 0.0458
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 44s 105ms/step - accuracy: 0.9778 - loss: 0.0717 - val_accuracy: 0.9892 - val_loss: 0.0421
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 44s 103ms/step - accuracy: 0.9807 - loss: 0.0619 - val_accuracy: 0.9905 - val_loss: 0.0363
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 46s 108ms/step - accuracy: 0.9840 - loss: 0.0516 - val_accuracy: 0.9908 - val_loss: 0.0354
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 44s 105ms/step - accuracy: 0.9833 - loss: 0.0531 - val_accuracy: 0.9908 - val_loss: 0.0329
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 43s 102ms/step - accuracy: 0.9858 - loss: 0.0452 - val_accuracy: 0.9918 - val_loss: 0.0305
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 43s 103ms/step - accuracy: 0.9871 - loss: 0.0398 - val_accuracy: 0.9902 - val_loss: 0.0313
# Epoch 10/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 44s 103ms/step - accuracy: 0.9869 - loss: 0.0395 - val_accuracy: 0.9928 - val_loss: 0.0266
# Epoch 11/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 43s 101ms/step - accuracy: 0.9878 - loss: 0.0368 - val_accuracy: 0.9920 - val_loss: 0.0264
# Epoch 12/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 44s 103ms/step - accuracy: 0.9890 - loss: 0.0362 - val_accuracy: 0.9932 - val_loss: 0.0280
# Epoch 13/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 43s 101ms/step - accuracy: 0.9902 - loss: 0.0297 - val_accuracy: 0.9930 - val_loss: 0.0238
# Epoch 14/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 43s 102ms/step - accuracy: 0.9897 - loss: 0.0287 - val_accuracy: 0.9935 - val_loss: 0.0252
# Epoch 15/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 43s 102ms/step - accuracy: 0.9886 - loss: 0.0314 - val_accuracy: 0.9930 - val_loss: 0.0240

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.02049626037478447
# Test accuracy: 0.992900013923645

# %%
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        keras.layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        keras.layers.MaxPooling2D(pool_size=(2, 2)),
        keras.layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
        keras.layers.MaxPooling2D(pool_size=(2, 2)),
        keras.layers.Flatten(),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(num_classes, activation="softmax"),
    ]
)

# Modify the optimizer here
total_params = model.count_params()
print(f"Total number of trainable parameters: {total_params}")
model.compile(loss="categorical_crossentropy", optimizer="sgd", metrics=["accuracy"])
model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# Total number of trainable parameters: 34826
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 50s 117ms/step - accuracy: 0.2725 - loss: 2.1301 - val_accuracy: 0.8765 - val_loss: 0.6213
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 44s 105ms/step - accuracy: 0.7635 - loss: 0.7471 - val_accuracy: 0.9253 - val_loss: 0.2946
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 44s 104ms/step - accuracy: 0.8616 - loss: 0.4510 - val_accuracy: 0.9445 - val_loss: 0.2113
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 45s 106ms/step - accuracy: 0.8992 - loss: 0.3320 - val_accuracy: 0.9550 - val_loss: 0.1715
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 44s 103ms/step - accuracy: 0.9173 - loss: 0.2765 - val_accuracy: 0.9615 - val_loss: 0.1474
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 45s 106ms/step - accuracy: 0.9286 - loss: 0.2379 - val_accuracy: 0.9665 - val_loss: 0.1304
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 44s 103ms/step - accuracy: 0.9336 - loss: 0.2204 - val_accuracy: 0.9685 - val_loss: 0.1197
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 45s 105ms/step - accuracy: 0.9399 - loss: 0.1970 - val_accuracy: 0.9713 - val_loss: 0.1090
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 45s 107ms/step - accuracy: 0.9450 - loss: 0.1847 - val_accuracy: 0.9725 - val_loss: 0.1026
# Epoch 10/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 44s 104ms/step - accuracy: 0.9463 - loss: 0.1777 - val_accuracy: 0.9742 - val_loss: 0.0972
# Epoch 11/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 44s 103ms/step - accuracy: 0.9504 - loss: 0.1644 - val_accuracy: 0.9752 - val_loss: 0.0927
# Epoch 12/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 44s 103ms/step - accuracy: 0.9527 - loss: 0.1583 - val_accuracy: 0.9775 - val_loss: 0.0874
# Epoch 13/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 45s 107ms/step - accuracy: 0.9582 - loss: 0.1436 - val_accuracy: 0.9773 - val_loss: 0.0845
# Epoch 14/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 45s 105ms/step - accuracy: 0.9564 - loss: 0.1429 - val_accuracy: 0.9767 - val_loss: 0.0824
# Epoch 15/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 44s 104ms/step - accuracy: 0.9587 - loss: 0.1373 - val_accuracy: 0.9788 - val_loss: 0.0785

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.08197969943284988
# Test accuracy: 0.9763000011444092

# %%
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        keras.layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        keras.layers.MaxPooling2D(pool_size=(2, 2)),
        keras.layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
        keras.layers.MaxPooling2D(pool_size=(2, 2)),
        keras.layers.Flatten(),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(num_classes, activation="softmax"),
    ]
)

# Modify the optimizer here
total_params = model.count_params()
print(f"Total number of trainable parameters: {total_params}")
model.compile(loss="categorical_crossentropy", optimizer="adadelta", metrics=["accuracy"])
model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# Total number of trainable parameters: 34826
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 45s 107ms/step - accuracy: 0.0903 - loss: 2.3239 - val_accuracy: 0.0940 - val_loss: 2.3110
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 43s 100ms/step - accuracy: 0.0981 - loss: 2.3127 - val_accuracy: 0.1243 - val_loss: 2.2980
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 42s 100ms/step - accuracy: 0.1176 - loss: 2.2982 - val_accuracy: 0.1443 - val_loss: 2.2851
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 42s 100ms/step - accuracy: 0.1317 - loss: 2.2879 - val_accuracy: 0.1692 - val_loss: 2.2721
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 59s 140ms/step - accuracy: 0.1542 - loss: 2.2739 - val_accuracy: 0.1957 - val_loss: 2.2589
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 42s 100ms/step - accuracy: 0.1731 - loss: 2.2614 - val_accuracy: 0.2208 - val_loss: 2.2455
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 43s 102ms/step - accuracy: 0.1938 - loss: 2.2482 - val_accuracy: 0.2555 - val_loss: 2.2315
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 46s 108ms/step - accuracy: 0.2124 - loss: 2.2347 - val_accuracy: 0.2918 - val_loss: 2.2170
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 43s 103ms/step - accuracy: 0.2354 - loss: 2.2210 - val_accuracy: 0.3265 - val_loss: 2.2018
# Epoch 10/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 42s 100ms/step - accuracy: 0.2571 - loss: 2.2077 - val_accuracy: 0.3645 - val_loss: 2.1859
# Epoch 11/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 43s 101ms/step - accuracy: 0.2840 - loss: 2.1910 - val_accuracy: 0.4013 - val_loss: 2.1690
# Epoch 12/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 43s 101ms/step - accuracy: 0.3080 - loss: 2.1751 - val_accuracy: 0.4443 - val_loss: 2.1511
# Epoch 13/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 44s 103ms/step - accuracy: 0.3295 - loss: 2.1583 - val_accuracy: 0.4953 - val_loss: 2.1318
# Epoch 14/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 44s 103ms/step - accuracy: 0.3503 - loss: 2.1415 - val_accuracy: 0.5447 - val_loss: 2.1113
# Epoch 15/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 42s 99ms/step - accuracy: 0.3781 - loss: 2.1227 - val_accuracy: 0.5863 - val_loss: 2.0892

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
model.summary()
# Out:
# Test loss: 2.0940639972686768
# Test accuracy: 0.5670999884605408
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┓
# ┃ Layer (type)                       ┃ Output Shape                  ┃     Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━┩
# │ conv2d_14 (Conv2D)                 │ (None, 26, 26, 32)            │         320 │
# ├────────────────────────────────────┼───────────────────────────────┼─────────────┤
# │ max_pooling2d_14 (MaxPooling2D)    │ (None, 13, 13, 32)            │           0 │
# ├────────────────────────────────────┼───────────────────────────────┼─────────────┤
# │ conv2d_15 (Conv2D)                 │ (None, 11, 11, 64)            │      18,496 │
# ├────────────────────────────────────┼───────────────────────────────┼─────────────┤
# │ max_pooling2d_15 (MaxPooling2D)    │ (None, 5, 5, 64)              │           0 │
# ├────────────────────────────────────┼───────────────────────────────┼─────────────┤
# │ flatten_7 (Flatten)                │ (None, 1600)                  │           0 │
# ├────────────────────────────────────┼───────────────────────────────┼─────────────┤
# │ dropout_7 (Dropout)                │ (None, 1600)                  │           0 │
# ├────────────────────────────────────┼───────────────────────────────┼─────────────┤
# │ dense_7 (Dense)                    │ (None, 10)                    │      16,010 │
# └────────────────────────────────────┴───────────────────────────────┴─────────────┘
#  Total params: 104,480 (408.12 KB)
#  Trainable params: 34,826 (136.04 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 69,654 (272.09 KB)

# %% [markdown]
# # A personal regression example

# %% [markdown]
# For this exercise, you will work on a dataset that is built from your personal student number as indicated in the assignment. If you have trouble with loading the data, place the data.csv file in your working directory.

# %%
try:
  data = pd.read_csv("./data.csv", header= None).values.T
  print("Succesfully loaded data")
except:
  try:
    data_url = "https://github.com/KULasagna/ANN_DL_public/blob/master/session1/data.csv?raw=true"
    data = pd.read_csv(data_url, header= None).values.T
    print("Succesfully loaded data")
  except:
    print(f"Please download the data.csv file from Toledo and place it in your working directory: {os.getcwd()}")
# Out:
# Succesfully loaded data

# %%
def dataset_generation(d1, d2, d3, d4, d5):
    T_new = (d1 * data[:, 2] + d2 * data[:, 3] + d3 * data[:, 4] + d4 * data[:, 5] + d5 * data[:, 6])/(d1 + d2 + d3 + d4 + d5)
    return T_new

x_values = data[:, 0:2]

# Put your own (decreasingly ordered) student number in the function
# e.g. u1024659 --> T_new =  dataset_generation(9, 6, 5, 4, 2)

T_new =  dataset_generation(9, 7, 7, 6, 4)

# Random subsampling to get the working dataset
idx = np.random.permutation(13600)

# training set
x_train = x_values[idx[0:2000]]
y_train = T_new[idx[0:2000]]

# test set
x_test = x_values[idx[2000:3000]]
y_test = T_new[idx[2000:3000]]


print('Number of training datapoints:', x_train.shape[0])
print('Number of testing datapoints:', x_test.shape[0])
# Out:
# Number of training datapoints: 2000
# Number of testing datapoints: 1000

# %%
x_train.shape
# Out:
# (2000, 2)

# %% [markdown]
# You can now plot the surface of the dataset. (Hint: use the function <tt> plot_trisurf </tt>)

# %%
fig, ax = plt.subplots(subplot_kw={'projection': '3d'})
ax.plot_trisurf(x_train[:,0], x_train[:,1], y_train, cmap='viridis', edgecolor='none')
# Add labels
ax.set_title("Training data")
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
# Show plot
plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection': '3d'})
ax.plot_trisurf(x_test[:,0], x_test[:,1], y_test, cmap='viridis', edgecolor='none')
# Add labels
ax.set_title("Test data")
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
# Show plot
plt.show()

# %% [markdown]
# In the following, we give an example of how to train a model. When you train yours, do not forget to validate it ! Hint: it is not enough to look at the training error. The hyperparameter values have voluntarily be set to give suboptimal results, you can do better than the proposed architecture !

# %%
l1_value = 1e-4
dropout_rate = 0.5

net = keras.Sequential(
    [
        keras.layers.Input(shape=[x_train.shape[1]]),
        keras.layers.Dense(
            units=1600
        ),
        keras.layers.Activation('relu'),
        keras.layers.Dense(
            units=5**5
        ),
        keras.layers.Activation('relu'),
        keras.layers.Dense(
            units=1600
        ),
        keras.layers.Activation('relu'),
        keras.layers.Dense(units=1)
    ]
)
'''
net = keras.Sequential(
    [
        keras.layers.Input(shape=[x_train.shape[1]]),
        keras.layers.Dense(units=1600, activation='relu'),
        keras.layers.Dense(units=5**5, activation='relu'),
        keras.layers.Dense(units=1600, activation='relu'),
        keras.layers.Dense(units=1)
    ]
)'''
net.compile(
    loss = keras.losses.MeanSquaredError(),
    optimizer = keras.optimizers.Adam()
)
callback1 = keras.callbacks.EarlyStopping(monitor='val_loss', patience=7, min_delta=1e-4, restore_best_weights=True)
callback2 = keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=1/np.sqrt(10), patience=3)
history = net.fit(x_train, y_train, validation_split=0.2, epochs=1000, batch_size=64, callbacks=[callback1, callback2], verbose=1)

plt.figure()
plt.xlabel('epoch')
plt.ylabel('training loss')
plt.plot(history.history['loss'], color= "firebrick")
plt.plot(history.history['val_loss'], color= 'teal')
plt.show()
print('Last training error:', history.history['loss'][-1])
print('Last validation error:', history.history['val_loss'][-1])
# Out:
# Epoch 1/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 258ms/step - loss: 2.9883 - val_loss: 0.4627 - learning_rate: 0.0010
# Epoch 2/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 300ms/step - loss: 0.2815 - val_loss: 0.1153 - learning_rate: 0.0010
# Epoch 3/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 278ms/step - loss: 0.0769 - val_loss: 0.0494 - learning_rate: 0.0010
# Epoch 4/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 331ms/step - loss: 0.0479 - val_loss: 0.0390 - learning_rate: 0.0010
# Epoch 5/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 289ms/step - loss: 0.0416 - val_loss: 0.0420 - learning_rate: 0.0010
# Epoch 6/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 271ms/step - loss: 0.0373 - val_loss: 0.0329 - learning_rate: 0.0010
# Epoch 7/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 294ms/step - loss: 0.0375 - val_loss: 0.0368 - learning_rate: 0.0010
# Epoch 8/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 276ms/step - loss: 0.0375 - val_loss: 0.0284 - learning_rate: 0.0010
# Epoch 9/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 323ms/step - loss: 0.0289 - val_loss: 0.0243 - learning_rate: 0.0010
# Epoch 10/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 264ms/step - loss: 0.0252 - val_loss: 0.0236 - learning_rate: 0.0010
# Epoch 11/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 313ms/step - loss: 0.0219 - val_loss: 0.0217 - learning_rate: 0.0010
# Epoch 12/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 263ms/step - loss: 0.0183 - val_loss: 0.0185 - learning_rate: 0.0010
# Epoch 13/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 323ms/step - loss: 0.0204 - val_loss: 0.0132 - learning_rate: 0.0010
# Epoch 14/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 263ms/step - loss: 0.0130 - val_loss: 0.0257 - learning_rate: 0.0010
# Epoch 15/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 291ms/step - loss: 0.0174 - val_loss: 0.0126 - learning_rate: 0.0010
# Epoch 16/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 274ms/step - loss: 0.0108 - val_loss: 0.0112 - learning_rate: 0.0010
# Epoch 17/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 319ms/step - loss: 0.0103 - val_loss: 0.0097 - learning_rate: 0.0010
# Epoch 18/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 263ms/step - loss: 0.0103 - val_loss: 0.0074 - learning_rate: 0.0010
# Epoch 19/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 362ms/step - loss: 0.0115 - val_loss: 0.0077 - learning_rate: 0.0010
# Epoch 20/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 276ms/step - loss: 0.0112 - val_loss: 0.0088 - learning_rate: 0.0010
# Epoch 21/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 314ms/step - loss: 0.0125 - val_loss: 0.0097 - learning_rate: 0.0010
# Epoch 22/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 268ms/step - loss: 0.0071 - val_loss: 0.0061 - learning_rate: 3.1623e-04
# Epoch 23/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 307ms/step - loss: 0.0044 - val_loss: 0.0061 - learning_rate: 3.1623e-04
# Epoch 24/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 260ms/step - loss: 0.0047 - val_loss: 0.0061 - learning_rate: 3.1623e-04
# Epoch 25/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 323ms/step - loss: 0.0046 - val_loss: 0.0058 - learning_rate: 3.1623e-04
# Epoch 26/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 420ms/step - loss: 0.0050 - val_loss: 0.0057 - learning_rate: 3.1623e-04
# Epoch 27/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 386ms/step - loss: 0.0048 - val_loss: 0.0059 - learning_rate: 3.1623e-04
# Epoch 28/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 413ms/step - loss: 0.0047 - val_loss: 0.0051 - learning_rate: 3.1623e-04
# Epoch 29/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 441ms/step - loss: 0.0043 - val_loss: 0.0052 - learning_rate: 3.1623e-04
# Epoch 30/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 476ms/step - loss: 0.0037 - val_loss: 0.0052 - learning_rate: 3.1623e-04
# Epoch 31/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 508ms/step - loss: 0.0047 - val_loss: 0.0067 - learning_rate: 3.1623e-04
# Epoch 32/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 519ms/step - loss: 0.0053 - val_loss: 0.0048 - learning_rate: 1.0000e-04
# Epoch 33/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 493ms/step - loss: 0.0036 - val_loss: 0.0048 - learning_rate: 1.0000e-04
# Epoch 34/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 409ms/step - loss: 0.0035 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 35/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 419ms/step - loss: 0.0031 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 36/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 434ms/step - loss: 0.0035 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 37/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 422ms/step - loss: 0.0037 - val_loss: 0.0048 - learning_rate: 1.0000e-04
# Epoch 38/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 414ms/step - loss: 0.0034 - val_loss: 0.0046 - learning_rate: 3.1623e-05
# Epoch 39/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 407ms/step - loss: 0.0031 - val_loss: 0.0045 - learning_rate: 3.1623e-05
# Epoch 40/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 434ms/step - loss: 0.0036 - val_loss: 0.0046 - learning_rate: 3.1623e-05
# Epoch 41/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 425ms/step - loss: 0.0029 - val_loss: 0.0047 - learning_rate: 3.1623e-05
# Epoch 42/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 420ms/step - loss: 0.0030 - val_loss: 0.0045 - learning_rate: 3.1623e-05
# Epoch 43/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 408ms/step - loss: 0.0041 - val_loss: 0.0045 - learning_rate: 1.0000e-05
# Epoch 44/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 443ms/step - loss: 0.0033 - val_loss: 0.0045 - learning_rate: 1.0000e-05
# Epoch 45/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 439ms/step - loss: 0.0037 - val_loss: 0.0045 - learning_rate: 1.0000e-05
# Epoch 46/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 443ms/step - loss: 0.0036 - val_loss: 0.0045 - learning_rate: 3.1623e-06
# Last training error: 0.003367348574101925
# Last validation error: 0.004506069701164961

# %% [markdown]
# Once a model is trained, you can use it to assess the final performance of the model on the test set.

# %%
y_pred = net.predict(x_test).squeeze(-1)
print('Final test error:', 0.5*((y_pred - y_test)**2).mean())
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Final test error: 0.0027723711775769918

# %%
fig, ax = plt.subplots(subplot_kw={'projection': '3d'})
ax.plot_trisurf(x_test[:,0], x_test[:,1], y_pred, cmap='viridis', edgecolor='none')
# Add labels
ax.set_title("Predicted Test data without regularization")
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
# Show plot
plt.show()

# %%
y_pred = net.predict(x_train).squeeze(-1)
print('Final test error:', 0.5*((y_pred - y_train)**2).mean())
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step
# Final test error: 0.0014578108781049912

# %%
fig, ax = plt.subplots(subplot_kw={'projection': '3d'})
ax.plot_trisurf(x_train[:,0], x_train[:,1], y_pred, cmap='viridis', edgecolor='none')
# Add labels
ax.set_title("Predicted Train data")
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
# Show plot
plt.show()
